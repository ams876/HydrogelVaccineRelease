# %%
pip install numpy==1.19.2
pip install scipy
pip install matplotlib==3.3.2

# %%
# %run StochasticVaccineRelease.py
# Out:
# {'D_high': 1.9999999999999996, 'D_low': 0.0, 'k_convert': 0.01, 'delta_k_convert': 0, 'numVaccine': 15, 'numSubvols': 10, 'vaccineSize': 0.05}
# ------
# {'D_high': 1.9999999999999996, 'D_low': 0.0, 'k_convert': 0.01, 'delta_k_convert': 0, 'numVaccine': 15, 'numSubvols': 10, 'vaccineSize': 0.05}

# %%
import math
def roundup(x):
    return int(math.ceil(x / 9)) *9

roundup(15)
# Out:
# 18
